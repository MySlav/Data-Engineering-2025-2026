# %% [markdown]
# <b><h1 style="font-size:30px;text-align: center;">- Date Engineering  - Exercise 4 -</h1></b>
# <b><h1 style="font-size:25px;text-align: center;">- Installing Prerequisites for Python Exercises -</h1></b>
#
# <div style="text-align:center; margin:16px 0 28px;">
#   <img
#     src="https://futsal-dinamo.hr/wp-content/uploads/2021/01/Algebra-Bernays.png"
#     alt="Algebra Bernays"
#     style="width:600px; max-width:60%; height:auto; margin-top:25px;"
#   >
# </div>
#
#
#
# ---------------------
# <b>*Made: October 2025.* </b>
#
# <b>*Author: Adjunct Lecturer Mislav Spajić, M.Eng. (Comp.)*</b>
#
# ---------------------

# %% [markdown]
# # Installing Prerequisites for Python Exercises

# %% [markdown]
# You can install packages in this environment using pip and conda. Shell command can be invoked using "!" at the beggining of the cell.

# %% [markdown]
# ### Installing missing no and ydata-profiling libraries  needed in other notebooks.

# %%
# !pip install -U missingno

# %%
# !pip install -U ydata-profiling

# %%
#Testing ydata profiling
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.DataFrame(np.random.rand(100, 5), columns=["a", "b", "c", "d", "e"])

# %%
profile = ProfileReport(df, title="Pandas Profiling Report")

# %%
# !conda install -y -c conda-forge ipywidgets jupyterlab_widgets

# %%
profile.to_notebook_iframe()

# %%
profile.to_file("your_report.html")
